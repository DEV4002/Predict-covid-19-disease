# %%
from tkinter import*
w=Tk()


w.title("COVID19 REPORT")
h1=Label(w,text="COVID19 REPORT",font=('arial',15,'bold'),borderwidth=5,relief="raise",bg="aqua")
h1.grid(row=1,column=1,columnspan=5)
##################################################################
h2=Label(w,text="FULL NAME",font=('arial',15,'bold'),relief="sunken",bg="green1")
h2.grid(row=2,column=1,columnspan=2)
h3=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1",)
h3.grid(row=2,column=3,columnspan=3)
######################################################################
h4=Label(w,text="MOBILE NO",font=('arial',15,'bold'),relief="sunken",bg="green1")
h4.grid(row=3,column=1,columnspan=2)
h5=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h5.grid(row=3,column=3,columnspan=3)
#####################################################################
h6=Label(w,text="AGE",font=('arial',15,'bold'),relief="sunken",bg="green1")
h6.grid(row=4,column=1,columnspan=2)
h7=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h7.grid(row=4,column=3,columnspan=3)
####################################################################
h8=Label(w,text="AADHAR",font=('arial',15,'bold'),relief="sunken",bg="green1")
h8.grid(row=5,column=1,columnspan=2)
h9=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h9.grid(row=5,column=3,columnspan=3)
#####################################################################
h10=Label(w,text="DISEASES",font=('arial',20,'bold'),relief="raise",bg="mediumspringgreen")
h10.grid(row=6,column=3,columnspan=2)
#####################################################################
# ROW NO 7
##########################################
h11=Label(w,text="SYMPTONS",font=('arial',15,'bold'),relief="sunken",bg="darkorchid1")
h11.grid(row=7,column=1,columnspan=2)

h12=Label(w,text="YES",font=('arial',15,'bold'),relief="raise",bg="darkorchid1")
h12.grid(row=7,column=4)

h13=Label(w,text="NO",font=('arial',15,'bold'),relief="raise",bg="darkorchid1")
h13.grid(row=7,column=5)
############################################
# row = 8
###########################################
h14=Label(w,text="BREATHING PROBLEM",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h14.grid(row=8,column=1,columnspan=2)
v1=IntVar()

h15=Radiobutton(w,variable=v1,value=1,bg="cyan")
h15.grid(row=8, column=4)

h16=Radiobutton(w,variable=v1,value=0,bg="cyan")
h16.grid(row=8,column=5)
######################################################
# ROW NO  9
######################################################
h17=Label(w,text="Fever",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h17.grid(row=9,column=1,columnspan=2)
v2=IntVar()

h18=Radiobutton(w,variable=v2,value=1,bg="cyan")
h18.grid(row=9, column=4)

h19=Radiobutton(w,variable=v2,value=0,bg="cyan")
h19.grid(row=9,column=5)
####################################################################
# ROW NO  10
#############################################################
h20=Label(w,text="dry Cough",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h20.grid(row=10,column=1,columnspan=2)
v3=IntVar()

h21=Radiobutton(w,variable=v3,value=1,bg="cyan")
h21.grid(row=10, column=4)

h22=Radiobutton(w,variable=v3,value=0,bg="cyan")
h22.grid(row=10,column=5)
####################################################################
# ROW NO  11
######################################################################
h23=Label(w,text="Sore throat",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h23.grid(row=11,column=1,columnspan=2)
v4=IntVar()

h24=Radiobutton(w,variable=v4,value=1,bg="cyan")
h24.grid(row=11, column=4)

h25=Radiobutton(w,variable=v4,value=0,bg="cyan")
h25.grid(row=11,column=5)
#############################################################################
# ROW NO  12
#########################################################################
h26=Label(w,text="Running Nose",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h26.grid(row=12,column=1,columnspan=2)
v5=IntVar()

h27=Radiobutton(w,variable=v5,value=1,bg="cyan")
h27.grid(row=12, column=4)

h28=Radiobutton(w,variable=v5,value=0,bg="cyan")
h28.grid(row=12,column=5)
####################################################################
# ROW NO  13
##################################################################
h29=Label(w,text="Asthma",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h29.grid(row=13,column=1,columnspan=2)
v6=IntVar()

h30=Radiobutton(w,variable=v6,value=1,bg="cyan")
h30.grid(row=13, column=4)

h31=Radiobutton(w,variable=v6,value=0,bg="cyan")
h31.grid(row=13,column=5)
######################################################################
# ROW NO  14
################################################################
h32=Label(w,text="Chronic Lung Disease",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h32.grid(row=14,column=1,columnspan=2)
v7=IntVar()

h33=Radiobutton(w,variable=v7,value=1,bg="cyan")
h33.grid(row=14, column=4)

h34=Radiobutton(w,variable=v7,value=0,bg="cyan")
h34.grid(row=14,column=5)
###################################################################
# ROW NO  15
##################################################################
h35=Label(w,text="Headache",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h35.grid(row=15,column=1,columnspan=2)
v8=IntVar()

h36=Radiobutton(w,variable=v8,value=1,bg="cyan")
h36.grid(row=15, column=4)

h37=Radiobutton(w,variable=v8,value=0,bg="cyan")
h37.grid(row=15,column=5)
#########################################################################
# ROW NO  16
#########################################################################
h38=Label(w,text="Heart Disease",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h38.grid(row=16,column=1,columnspan=2)
v9=IntVar()

h39=Radiobutton(w,variable=v9,value=1,bg="cyan")
h39.grid(row=16, column=4)

h40=Radiobutton(w,variable=v9,value=0,bg="cyan")
h40.grid(row=16,column=5)
###########################################################################
# ROW NO  17
######################################################################
h41=Label(w,text="Diabetes",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h41.grid(row=17,column=1,columnspan=2)
v10=IntVar()

h42=Radiobutton(w,variable=v10,value=1,bg="cyan")
h42.grid(row=17, column=4)

h43=Radiobutton(w,variable=v10,value=0,bg="cyan")
h43.grid(row=17,column=5)
###########################################################################
# ROW NO  18
######################################################################
h44=Label(w,text="Hyper Tenson",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h44.grid(row=18,column=1,columnspan=2)
v11=IntVar()

h45=Radiobutton(w,variable=v11,value=1,bg="cyan")
h45.grid(row=18, column=4)

h46=Radiobutton(w,variable=v11,value=0,bg="cyan")
h46.grid(row=18,column=5)
###########################################################################
# ROW NO  19
######################################################################
h47=Label(w,text="Abroad travel",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h47.grid(row=19,column=1,columnspan=2)
v12=IntVar()

h48=Radiobutton(w,variable=v12,value=1,bg="cyan")
h48.grid(row=19, column=4)

h49=Radiobutton(w,variable=v12,value=0,bg="cyan")
h49.grid(row=19,column=5)
###########################################################################
# ROW NO  20
######################################################################
h50=Label(w,text="Contact With COVID patient",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h50.grid(row=20,column=1,columnspan=2)
v13=IntVar()

h51=Radiobutton(w,variable=v13,value=1,bg="cyan")
h51.grid(row=20, column=4)

h52=Radiobutton(w,variable=v13,value=0,bg="cyan")
h52.grid(row=20,column=5)
###########################################################################
# ROW NO  21
######################################################################
h53=Label(w,text="Attended Large Gathering",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h53.grid(row=21,column=1,columnspan=2)
v14=IntVar()

h54=Radiobutton(w,variable=v14,value=1,bg="cyan")
h54.grid(row=21, column=4)

h55=Radiobutton(w,variable=v14,value=0,bg="cyan")
h55.grid(row=21,column=5)
###########################################################################
# ROW NO  22
######################################################################
h56=Label(w,text="Visited public exposed places",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h56.grid(row=22,column=1,columnspan=2)
v15=IntVar()

h57=Radiobutton(w,variable=v15,value=1,bg="cyan")
h57.grid(row=22, column=4)

h58=Radiobutton(w,variable=v15,value=0,bg="cyan")
h58.grid(row=22,column=5)
###########################################################################
# ROW NO  23
######################################################################
h59=Label(w,text="Family working in public Exposed places",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h59.grid(row=23,column=1,columnspan=2)
v16=IntVar()


h60=Radiobutton(w,variable=v16,value=1,bg="cyan")
h60.grid(row=23, column=4)

h61=Radiobutton(w,variable=v16,value=0,bg="cyan")
h61.grid(row=23,column=5)
###########################################################################
# ROW NO  24
######################################################################
h62=Label(w,text="Wearing Masks",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h62.grid(row=24,column=1,columnspan=2)
v17=IntVar()

h63=Radiobutton(w,variable=v17,value=1,bg="cyan")
h63.grid(row=24, column=4)

h64=Radiobutton(w,variable=v17,value=0,bg="cyan")
h64.grid(row=24,column=5)
###########################################################################
# ROW NO  25
######################################################################
h65=Label(w,text="Sanitization from Market ",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h65.grid(row=25,column=1,columnspan=2)
v18=IntVar()

h66=Radiobutton(w,variable=v18,value=1,bg="cyan")
h66.grid(row=25, column=4)

h67=Radiobutton(w,variable=v18,value=0,bg="cyan")
h67.grid(row=25,column=5)
#########################################################################
# Row no 26
###########################################################
h68=Button(w,text="SUBMIT",font=('arial',20,'bold'),relief="raise",bg="red")
h68.grid(row=26,column=1,columnspan=2)

h69=Button(w,text="RESET",font=('arial',20,'bold'),relief="raise",bg="lawngreen")
h69.grid(row=26,column=3,columnspan=2)
#################################################################################
# row no 27
####################################################################################
disp=Entry(w,font=('arial',30,'bold'),relief="raise",bg="khaki1")
disp.grid(row=27,column=1,columnspan=5)

w.mainloop()

# %%
# Covid 19 prediction project
# data sheet implement
import pandas as pd
df= pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\PYTHONSOFT\\COVID19PROJECT\\coviddata.csv")
##############################
# convert the all column value to numeric
#############################

df['COVID-19']=df['COVID-19'].map({'Yes':1,"No":0})
df['Breathing Problem']=df['Breathing Problem'].map({'Yes':1,"No":0})
df['Fever']=df['Fever'].map({'Yes':1,"No":0})
df['Dry Cough']=df['Dry Cough'].map({'Yes':1,"No":0})
df['Sore throat']=df['Sore throat'].map({'Yes':1,"No":0})
df['Running Nose']=df['Running Nose'].map({'Yes':1,"No":0})
df['Asthma']=df['Asthma'].map({'Yes':1,"No":0})
df['Chronic Lung Disease']=df['Chronic Lung Disease'].map({'Yes':1,"No":0})
df['Headache']=df['Headache'].map({'Yes':1,"No":0})
df['Heart Disease']=df['Heart Disease'].map({'Yes':1,"No":0})
df['Diabetes']=df['Diabetes'].map({'Yes':1,"No":0})
df['Hyper Tension']=df['Hyper Tension'].map({'Yes':1,"No":0})

df['Abroad travel']=df['Abroad travel'].map({'Yes':1,"No":0})
df['Contact with COVID Patient']=df['Contact with COVID Patient'].map({'Yes':1,"No":0})
df['Attended Large Gathering']=df['Attended Large Gathering'].map({'Yes':1,"No":0})
df['Visited Public Exposed Places']=df['Visited Public Exposed Places'].map({'Yes':1,"No":0})
df['Family working in Public Exposed Places']=df['Family working in Public Exposed Places'].map({'Yes':1,"No":0})
df['Wearing Masks']=df['Wearing Masks'].map({'Yes':1,"No":0})
df['Sanitization from Market']=df['Sanitization from Market'].map({'Yes':1,"No":0})
df.sample(5)
#######################################################
# separate the input and output
#################################################
X=df.drop(columns=['COVID-19'])
y=df['COVID-19']

####################################################
# spilt the data set for terainning and testing
###################################################
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

##############################################################################
import warnings
warnings.filterwarnings('ignore')
def knn():
    from sklearn.neighbors import KNeighborsClassifier
    K=KNeighborsClassifier(n_neighbors=50)
    # train the modell by using 120 flower data
    K.fit(X_train,y_train)
    y_pred_knn=K.predict(X_test)
    y_pred_knn
    #find accuracy of knn model
    
    from sklearn.metrics import accuracy_score
    acc_knn=accuracy_score(y_test,y_pred_knn)
    acc_knn=round(acc_knn*100,2)
    print("accuracy in knn model is",acc_knn,"%")
def lg():
    # implement logistic regression
    from sklearn.linear_model import LogisticRegression 
    L=LogisticRegression()
    L.fit(X_train,y_train)
    y_pred_lg=L.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc_lg=accuracy_score(y_test,y_pred_lg)
    acc_lg=round(acc_lg*100,2)
    print("accuracy in logistic reg model is",acc_lg,"%")
def dt():
    global acc_dt
    global D
    from sklearn.tree import DecisionTreeClassifier
    D=DecisionTreeClassifier()
    D.fit(X_train,y_train)
    y_pred_dt=D.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc_dt=accuracy_score(y_test,y_pred_dt)
    acc_dt=round(acc_dt*100,2)
    print("accuracy in decision treee model is ",acc_dt,"%")
def nb():
    from sklearn.naive_bayes import GaussianNB
    N=GaussianNB()
    N.fit(X_train,y_train)
    y_pred_nb=N.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc_nb=accuracy_score(y_test,y_pred_nb)
    acc_nb=round(acc_nb*100,2)
    print("accuracy in decision treee model is ",acc_nb,"%")
def SUBMIT():
    dt()
    BreathingProblem =int(v1.get())
    Fever=	int(v2.get())
    DryCough = int(v3.get())
    Sorethroat=int(v4.get())
    RunningNose=int(v5.get())
    Asthma	=int(v6.get())
    ChronicLungDisease=int(v7.get())
    Headache=int(v8.get())
    HeartDisease=int(v9.get())
    Diabetes=int(v10.get())
    HyperTension=int(v11.get())
    Abroadtravel=int(v12.get())
    ContactwithCOVIDPatient=int(v13.get())
    AttendedLargeGathering=int(v14.get())
    VisitedPublicExposedPlaces=	int(v15.get())
    FamilyworkinginPublicExposedPlaces =int(v16.get())
    WearingMasks=int(v17.get())
    SanitizationfromMarket=int(v18.get())
    result=D.predict([[BreathingProblem,Fever,DryCough,Sorethroat,RunningNose,Asthma,ChronicLungDisease,Headache,HeartDisease,Diabetes,HyperTension,Abroadtravel,ContactwithCOVIDPatient,AttendedLargeGathering,VisitedPublicExposedPlaces,FamilyworkinginPublicExposedPlaces,WearingMasks,SanitizationfromMarket]])
    if result[0]==0:
        res="@YOU ARE NEGATIVE@"
    else :
        res="!!YOU ARE POSITIVE!!"
    disp.insert(0,f'{res}')

    
    
def RESET():
    
    v1.delete(0,END)
    v2.delete(0,END)
    v3.delete(0,END)
    v4.delete(0,END)
    v5.delete(0,END)
    v6.delete(0,END)
    v7.delete(0,END)
    v8.delete(0,END)
    v9.delete(0,END)
    v10.delete(0,END)
    v11.delete(0,END)
    v12.delete(0,END)
    v13.delete(0,END)
    v14.delete(0,END)
    v15.delete(0,END)
    v16.delete(0,END)
    v17.delete(0,END)
    v18.delete(0,END)


import warnings
warnings.filterwarnings('ignore')
from tkinter import*
w=Tk()

w.resizable(0,0)
w.title("COVID19 REPORT")
h1=Label(w,text="COVID19 REPORT",font=('arial',15,'bold'),borderwidth=5,relief="raise",bg="aqua")
h1.grid(row=1,column=1,columnspan=5)
##################################################################
h2=Label(w,text="FULL NAME",font=('arial',15,'bold'),relief="sunken",bg="green1")
h2.grid(row=2,column=1,columnspan=2)
h3=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1",)
h3.grid(row=2,column=3,columnspan=3)
######################################################################
h4=Label(w,text="MOBILE NO",font=('arial',15,'bold'),relief="sunken",bg="green1")
h4.grid(row=3,column=1,columnspan=2)
h5=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h5.grid(row=3,column=3,columnspan=3)
#####################################################################
h6=Label(w,text="AGE",font=('arial',15,'bold'),relief="sunken",bg="green1")
h6.grid(row=4,column=1,columnspan=2)
h7=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h7.grid(row=4,column=3,columnspan=3)
####################################################################
h8=Label(w,text="AADHAR",font=('arial',15,'bold'),relief="sunken",bg="green1")
h8.grid(row=5,column=1,columnspan=2)
h9=Entry(w,font=('arial',15,'bold'),relief="solid",bg="khaki1")
h9.grid(row=5,column=3,columnspan=3)
#####################################################################
h10=Label(w,text="DISEASES",font=('arial',20,'bold'),relief="raise",bg="mediumspringgreen")
h10.grid(row=6,column=3,columnspan=2)
#####################################################################
# ROW NO 7
##########################################
h11=Label(w,text="SYMPTONS",font=('arial',15,'bold'),relief="sunken",bg="darkorchid1")
h11.grid(row=7,column=1,columnspan=2)

h12=Label(w,text="YES",font=('arial',15,'bold'),relief="raise",bg="darkorchid1")
h12.grid(row=7,column=4)

h13=Label(w,text="NO",font=('arial',15,'bold'),relief="raise",bg="darkorchid1")
h13.grid(row=7,column=5)
############################################
# row = 8
###########################################
h14=Label(w,text="BREATHING PROBLEM",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h14.grid(row=8,column=1,columnspan=2)
v1=IntVar()

h15=Radiobutton(w,variable=v1,value=1,bg="cyan")
h15.grid(row=8, column=4)

h16=Radiobutton(w,variable=v1,value=0,bg="cyan")
h16.grid(row=8,column=5)
######################################################
# ROW NO  9
######################################################
h17=Label(w,text="Fever",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h17.grid(row=9,column=1,columnspan=2)
v2=IntVar()

h18=Radiobutton(w,variable=v2,value=1,bg="cyan")
h18.grid(row=9, column=4)

h19=Radiobutton(w,variable=v2,value=0,bg="cyan")
h19.grid(row=9,column=5)
####################################################################
# ROW NO  10
#############################################################
h20=Label(w,text="dry Cough",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h20.grid(row=10,column=1,columnspan=2)
v3=IntVar()

h21=Radiobutton(w,variable=v3,value=1,bg="cyan")
h21.grid(row=10, column=4)

h22=Radiobutton(w,variable=v3,value=0,bg="cyan")
h22.grid(row=10,column=5)
####################################################################
# ROW NO  11
######################################################################
h23=Label(w,text="Sore throat",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h23.grid(row=11,column=1,columnspan=2)
v4=IntVar()

h24=Radiobutton(w,variable=v4,value=1,bg="cyan")
h24.grid(row=11, column=4)

h25=Radiobutton(w,variable=v4,value=0,bg="cyan")
h25.grid(row=11,column=5)
#############################################################################
# ROW NO  12
#########################################################################
h26=Label(w,text="Running Nose",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h26.grid(row=12,column=1,columnspan=2)
v5=IntVar()

h27=Radiobutton(w,variable=v5,value=1,bg="cyan")
h27.grid(row=12, column=4)

h28=Radiobutton(w,variable=v5,value=0,bg="cyan")
h28.grid(row=12,column=5)
####################################################################
# ROW NO  13
##################################################################
h29=Label(w,text="Asthma",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h29.grid(row=13,column=1,columnspan=2)
v6=IntVar()

h30=Radiobutton(w,variable=v6,value=1,bg="cyan")
h30.grid(row=13, column=4)

h31=Radiobutton(w,variable=v6,value=0,bg="cyan")
h31.grid(row=13,column=5)
######################################################################
# ROW NO  14
################################################################
h32=Label(w,text="Chronic Lung Disease",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h32.grid(row=14,column=1,columnspan=2)
v7=IntVar()

h33=Radiobutton(w,variable=v7,value=1,bg="cyan")
h33.grid(row=14, column=4)

h34=Radiobutton(w,variable=v7,value=0,bg="cyan")
h34.grid(row=14,column=5)
###################################################################
# ROW NO  15
##################################################################
h35=Label(w,text="Headache",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h35.grid(row=15,column=1,columnspan=2)
v8=IntVar()

h36=Radiobutton(w,variable=v8,value=1,bg="cyan")
h36.grid(row=15, column=4)

h37=Radiobutton(w,variable=v8,value=0,bg="cyan")
h37.grid(row=15,column=5)
#########################################################################
# ROW NO  16
#########################################################################
h38=Label(w,text="Heart Disease",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h38.grid(row=16,column=1,columnspan=2)
v9=IntVar()

h39=Radiobutton(w,variable=v9,value=1,bg="cyan")
h39.grid(row=16, column=4)

h40=Radiobutton(w,variable=v9,value=0,bg="cyan")
h40.grid(row=16,column=5)
###########################################################################
# ROW NO  17
######################################################################
h41=Label(w,text="Diabetes",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h41.grid(row=17,column=1,columnspan=2)
v10=IntVar()

h42=Radiobutton(w,variable=v10,value=1,bg="cyan")
h42.grid(row=17, column=4)

h43=Radiobutton(w,variable=v10,value=0,bg="cyan")
h43.grid(row=17,column=5)
###########################################################################
# ROW NO  18
######################################################################
h44=Label(w,text="Hyper Tenson",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h44.grid(row=18,column=1,columnspan=2)
v11=IntVar()

h45=Radiobutton(w,variable=v11,value=1,bg="cyan")
h45.grid(row=18, column=4)

h46=Radiobutton(w,variable=v11,value=0,bg="cyan")
h46.grid(row=18,column=5)
###########################################################################
# ROW NO  19
######################################################################
h47=Label(w,text="Abroad travel",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h47.grid(row=19,column=1,columnspan=2)
v12=IntVar()

h48=Radiobutton(w,variable=v12,value=1,bg="cyan")
h48.grid(row=19, column=4)

h49=Radiobutton(w,variable=v12,value=0,bg="cyan")
h49.grid(row=19,column=5)
###########################################################################
# ROW NO  20
######################################################################
h50=Label(w,text="Contact With COVID patient",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h50.grid(row=20,column=1,columnspan=2)
v13=IntVar()

h51=Radiobutton(w,variable=v13,value=1,bg="cyan")
h51.grid(row=20, column=4)

h52=Radiobutton(w,variable=v13,value=0,bg="cyan")
h52.grid(row=20,column=5)
###########################################################################
# ROW NO  21
######################################################################
h53=Label(w,text="Attended Large Gathering",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h53.grid(row=21,column=1,columnspan=2)
v14=IntVar()

h54=Radiobutton(w,variable=v14,value=1,bg="cyan")
h54.grid(row=21, column=4)

h55=Radiobutton(w,variable=v14,value=0,bg="cyan")
h55.grid(row=21,column=5)
###########################################################################
# ROW NO  22
######################################################################
h56=Label(w,text="Visited public exposed places",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h56.grid(row=22,column=1,columnspan=2)
v15=IntVar()

h57=Radiobutton(w,variable=v15,value=1,bg="cyan")
h57.grid(row=22, column=4)

h58=Radiobutton(w,variable=v15,value=0,bg="cyan")
h58.grid(row=22,column=5)
###########################################################################
# ROW NO  23
######################################################################
h59=Label(w,text="Family working in public Exposed places",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h59.grid(row=23,column=1,columnspan=2)
v16=IntVar()


h60=Radiobutton(w,variable=v16,value=1,bg="cyan")
h60.grid(row=23, column=4)

h61=Radiobutton(w,variable=v16,value=0,bg="cyan")
h61.grid(row=23,column=5)
###########################################################################
# ROW NO  24
######################################################################
h62=Label(w,text="Wearing Masks",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h62.grid(row=24,column=1,columnspan=2)
v17=IntVar()

h63=Radiobutton(w,variable=v17,value=1,bg="cyan")
h63.grid(row=24, column=4)

h64=Radiobutton(w,variable=v17,value=0,bg="cyan")
h64.grid(row=24,column=5)
###########################################################################
# ROW NO  25
######################################################################
h65=Label(w,text="Sanitization from Market ",font=('arial',12,'bold'),relief="raise",bg="yellow1")
h65.grid(row=25,column=1,columnspan=2)
v18=IntVar()

h66=Radiobutton(w,variable=v18,value=1,bg="cyan")
h66.grid(row=25, column=4)

h67=Radiobutton(w,variable=v18,value=0,bg="cyan")
h67.grid(row=25,column=5)
#########################################################################
# Row no 26
###########################################################
h68=Button(w,text="SUBMIT",font=('arial',20,'bold'),relief="raise",bg="red",fg="lawngreen",command=SUBMIT)
h68.grid(row=26,column=1,columnspan=2)

h69=Button(w,text="RESET",font=('arial',20,'bold'),relief="raise",bg="lawngreen",fg="red",command=RESET)
h69.grid(row=26,column=3,columnspan=2)
#################################################################################
# row no 27
####################################################################################
disp=Entry(w,font=('arial',50,'bold'),relief="raise",bg="khaki1")
disp.grid(row=14,column=6,columnspan=5)

w.mainloop()
# Out:
# accuracy in decision treee model is  98.53 %
